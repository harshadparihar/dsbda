# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import load_dataset

# %%
import pandas as pd

# %%
data = sns.load_dataset('titanic')
#tips dataset
tip = sns.load_dataset('tips')
data.describe()
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.countplot(data['survived'])
#plt.show(data['survived'])
# Out:
# <AxesSubplot: ylabel='count'>

# %%
data['sex'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.hist(data['age'], bins=5)
plt.show()

# %%
sns.distplot(data['survived']) 
plt.show()
# Out:
#   Cell In[17], line 1
#     sns.distplot(data['survived'])
#                                   ^
# SyntaxError: invalid non-printable character U+00A0

# %%
sns.scatterplot(tip['total_bill'])
# Out:
# <AxesSubplot: ylabel='total_bill'>

# %%
sns.scatterplot(tip['tip'])
plt.show()

# %%
sns.scatterplot(tip["total_bill"], tip["tip"],hue=tip["sex"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 sns.scatterplot(tip["total_bill"], tip["tip"],hue=tip["sex"])
#       2 plt.show()
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given
